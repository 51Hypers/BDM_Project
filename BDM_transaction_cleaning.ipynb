# %%
import pandas as pd

df = pd.read_excel('/content/Transactions 01-09-2024 to 30-09-2024.xlsx', header=1)

# %%
df.head()
# Out:
#                                            Medicine Opening Stock Purchase  \
# 0                   MONTICOPE A STRIP OF 10 TABLETS          0::0        0
# 1  PULMOCARE STRAWBERRY FLAVOUR TIN OF 200GM POWDER          0::0        0
# 2                             RESPISMART N  TAB 10S         15::5        0
# 3                            BINAFIDE  RESPULES 0.5         10::0        0
# 4                      BINAFIDE DUO  RESPULES 2.5ML          0::0        0
#
#   Sales Closing Stock
# 0  0::2          1::3
# 1     1             0
# 2  0::2          5::9
# 3     1             1
# 4     1            11

# %%
df.rename(columns={'Medicine                                                 Opening Stock  Purchase  Sales  Closing Stock':'Medicine', 'Unnamed: 1':'Opening Stock', 'Unnamed: 2':'Purchase', 'Unnamed: 3':'Sales', 'Unnamed: 4':'Closing Stock'}, inplace=True)

# %%
df.columns
# Out:
# Index(['Medicine', 'Opening Stock', 'Purchase', 'Sales', 'Closing Stock'], dtype='object')

# %%
df.Medicine.isna().sum()
# Out:
# 31

# %%
df.shape
# Out:
# (1062, 5)

# %%
df = df.dropna(subset=['Medicine'])

# %%
df.Medicine.isna().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# Medicine         0
# Opening Stock    0
# Purchase         0
# Sales            0
# Closing Stock    0
# dtype: int64

# %%
df = df.dropna(subset=['Purchase'])

# %%
df.to_csv("T4_cleaned.csv", index=False)

# %%
df1 = pd.read_csv('/content/T1_cleaned.csv')
df2 = pd.read_csv('/content/T2_cleaned.csv')
df3 = pd.read_csv('/content/T3_cleaned.csv')
df4 = pd.read_csv('/content/T4_cleaned.csv')

# %%
df4.head()
# Out:
#                                            Medicine Opening Stock Purchase  \
# 0                   MONTICOPE A STRIP OF 10 TABLETS          0::0        0
# 1  PULMOCARE STRAWBERRY FLAVOUR TIN OF 200GM POWDER          0::0        0
# 2                             RESPISMART N  TAB 10S         15::5        0
# 3                            BINAFIDE  RESPULES 0.5         10::0        0
# 4                      BINAFIDE DUO  RESPULES 2.5ML          0::0        0
#
#   Sales Closing Stock
# 0  0::2          1::3
# 1     1             0
# 2  0::2          5::9
# 3     1             1
# 4     1            11

# %%
combined_df = pd.concat([df1, df2, df3, df4], ignore_index=False)

# %%
combined_df.head()
# Out:
#                                             Medicine Opening Stock Purchase  \
# 0                          LACTOGEN 1 POWDER 1KG TIN          0::0        1
# 1  NESTLE NAN PRO 1 STARTER INFANT FORMULA POWDER...          0::0        2
# 2                                PLACIDA PLUS TABLET          0::0        0
# 3                               SUCRAFIL O GEL 200ML          0::0        0
# 4                  NS 100ML INJECTION 100 MILLILITRE        207::0        0
#
#   Sales Closing Stock
# 0     0             0
# 1     0             0
# 2  0::5             0
# 3     1             2
# 4     3             0

# %%
combined_df.columns
# Out:
# Index(['Medicine', 'Opening Stock', 'Purchase', 'Sales', 'Closing Stock'], dtype='object')

# %%
combined_df.isna().sum()
# Out:
# Medicine         0
# Opening Stock    0
# Purchase         0
# Sales            0
# Closing Stock    0
# dtype: int64

# %%
combined_df.query('Medicine=="Medicine"')
# Out:
#       Medicine  Opening Stock  Purchase  Sales  Closing Stock
# 30    Medicine  Opening Stock  Purchase  Sales  Closing Stock
# 63    Medicine  Opening Stock  Purchase  Sales  Closing Stock
# 96    Medicine  Opening Stock  Purchase  Sales  Closing Stock
# 129   Medicine  Opening Stock  Purchase  Sales  Closing Stock
# 162   Medicine  Opening Stock  Purchase  Sales  Closing Stock
# ...        ...            ...       ...    ...            ...
# 888   Medicine  Opening Stock  Purchase  Sales  Closing Stock
# 921   Medicine  Opening Stock  Purchase  Sales  Closing Stock
# 954   Medicine  Opening Stock  Purchase  Sales  Closing Stock
# 987   Medicine  Opening Stock  Purchase  Sales  Closing Stock
# 1020  Medicine  Opening Stock  Purchase  Sales  Closing Stock
#
# [124 rows x 5 columns]

# %%
combined_df.Medicine.drop

# %%
# Filter out rows where the "Medicine" column has the value "Medicine"
clean_df = combined_df[combined_df['Medicine'] != 'Medicine']

# %%
clean_df.head()
# Out:
#                                             Medicine Opening Stock Purchase  \
# 0                          LACTOGEN 1 POWDER 1KG TIN          0::0        1
# 1  NESTLE NAN PRO 1 STARTER INFANT FORMULA POWDER...          0::0        2
# 2                                PLACIDA PLUS TABLET          0::0        0
# 3                               SUCRAFIL O GEL 200ML          0::0        0
# 4                  NS 100ML INJECTION 100 MILLILITRE        207::0        0
#
#   Sales Closing Stock
# 0     0             0
# 1     0             0
# 2  0::5             0
# 3     1             2
# 4     3             0

# %%
clean_df.query('Medicine=="Medicine"')
# Out:
# Empty DataFrame
# Columns: [Medicine, Opening Stock, Purchase, Sales, Closing Stock]
# Index: []

# %%
combined_df = clean_df

# %%
combined_df.query('Medicine=="Medicine"')
# Out:
# Empty DataFrame
# Columns: [Medicine, Opening Stock, Purchase, Sales, Closing Stock]
# Index: []

# %%
combined_df.isna().sum()
# Out:
# Medicine         0
# Opening Stock    0
# Purchase         0
# Sales            0
# Closing Stock    0
# dtype: int64

# %%
combined_df.to_csv("OpeningClosing_Stock_Combined.csv", index=False)
